# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удали этот текст и вместо него напиши свой комментарий 🙂
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# **Импортируем библиотеки и изучаем общую информацию о полученном датафрейме**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Все библиотеки лучше импортировать отдельно в первой ячейке. Это позволит тебе в любой момент добавить ещё одну библиотеку без перезаписи переменных.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Спасибо за совет. Так и сделаю)
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
display(data)
pd.set_option('display.max_columns', None)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Обрати внимание, что часть столбцов заменилась на "...". Чтобы это исправить, нужно увеличить максимальное количество отображающихся столбцов командой
#
# 	pd.set_option('display.max_columns', None)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Хорошо, подправил
# </div>

# %% [markdown]
# **Построим общую гистограмму для всех числовых столбцов таблицы**

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Графики построено верно!
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Здесь необходимо написать короткий вывод о проблемах с данными (пропуски, дубликаты, неверный тип данных, странные значения и т.д.)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Краткий вывод написал ниже
# </div>

# %% [markdown]
# После ознакомления с данными были определены следующие проблемы:
# - нарушение стиля в названиях некоторых столбцов
# - пропущенные значения в 14 стобцах
# - несоотвествие типов, необходим перевод данных в корректные форматы
# - возможны явные/неявные дубликаты
# - стоить проверить данные на выбросы и аномальные значения
#
# На данный момент можно утверждать, что этих данных достаточно для проверки требуемых гипотез. Скорее всего данные были взяты из разных источников - одна из возможных причин наличия пропусков значений в некоторых столбцах, а также некорректное заполнение первоисточников исполнителем.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# **Для начала исправим столбцы с нарушением стиля в названиях:**

# %%
data.rename(columns={'cityCenters_nearest': 'city_centers_nearest', 
                     'parks_around3000': 'parks_around_3000', 
                     'ponds_around3000': 'ponds_around_3000', 
                     'studio': 'is_studio', 
                     'open_plan': 'is_open_plan'}, inplace=True)
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'is_studio', 'is_open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Молодец! Так датафрейм будет более аккуратным
# </div>

# %% [markdown]
# **После приведения названий всех столбцов к единому стилю - определяем пропущенные значения и работаем с ними:**

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# is_studio                   0
# is_open_plan                0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Во всех столбцах с пропущенными значениями оставляем Null, т.к. по-большей части данные в них попросту не заполнили, кроме столбцов:
# - **'balcony'**, т.к. пропуск может означать, что балкон попросту отсутствует, присвоим этому столбцу 0;
# - **'is_apartment'**, т.к. скорее-всего пропуск означает, что это не апартаменты, поэтому присвоим False;
# - **'parks_around_3000'**, т.к. пропуск означает что парков в радиусе 3км нет, заменим их на 0:
# - **'parks_nearest'**, по аналогичной причине заменим их на 0:
# - **'ponds_around_3000'**, т.к. пропуск означает что прудов в радиусе 3км нет, заменим их на 0:
# - **'ponds_nearest'**, по аналогичной причине заменим их на 0:

# %%
data['balcony'] = data['balcony'].fillna(0).astype('int')
data['is_apartment'] = data['is_apartment'].fillna('False')
data['parks_around_3000'] = data['parks_around_3000'].fillna(0).astype('int')
data['parks_nearest'] = data['parks_nearest'].fillna(0).astype('int')
data['ponds_around_3000'] = data['ponds_around_3000'].fillna(0).astype('int')
data['ponds_nearest'] = data['ponds_nearest'].fillna(0).astype('int')

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Методы fillna и astype можно применить к нескольким столбцам одновременно
#
# 	df.astype({ "col1": "float64", "col2": "int64"})
# <br>Если столбцов более двух, то можно применить цикл for для автоматизации процесса
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Давай ещё заполним пропуски в столбце с высотой потолков, тем более мы можем достаточно точно их восстановить так как основная часть данных в этом столбце находится в небольшом диапазоне.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Ниже отдельно поработал со столбцом 'ceiling_height'
# <br>Сначала перевел значения в этом столбце в вещественный тип
# <br>Затем записал пустые места высоты потолка по медиане, посчитал этот вариант самым оптимальным
# <br>На всякий случай проверил среднюю высоту потолка из всей выборки, результат удовлетворил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %%
data['ceiling_height']=data['ceiling_height'].astype('float')

median_height=data['ceiling_height'].median()
data['ceiling_height'].fillna(median_height,inplace=True)
data['ceiling_height'].mean()
# Out:
# 2.724358411747331

# %%
data['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Теперь поработаем с типами данных:**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  is_studio             23699 non-null  bool
#  11  is_open_plan          23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Сменим тип данных для следующих столбцов:
# - **first_day_exposition** - на 'date'
# - **is_apartment** - на 'bool'
#
# Изменение типа для стобца 'first_day_exposition' - для удобство работы с датой; для стобца 'is_apartment' - с булевым значением работать будет проще.
#
# Остальные столбцы, требующие изменения типа были обработаны при работе с пропусками.

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'],format='%Y-%m-%dT%H:%M:%S')
data['is_apartment'] = data['is_apartment'].map({'False':False, 'True':True})

# %% [markdown]
# **Изучим уникальные значения.**
#
# Для этого сначала посчитаем их кол-во:

# %%
print(data['locality_name'].unique().shape[0])
# Out:
# 365

# %% [markdown]
# Для устранения неявных дубликатов:
# - приведем всё к нижнему регистру
# - заменим все "ё" на "е"
# - заменим "городской поселок" на "поселок городского типа"
# - проверим наличие явных дубликатов

# %%
data['locality_name'] = data['locality_name'].str.lower()

data['locality_name'] = data['locality_name'].str.replace('ё', 'е')

data['locality_name'] = data['locality_name'].str.replace('городской поселок','поселок городского типа')

data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Супер! Здесь всё верно)
# </div>

# %% [markdown]
# **Найдем и устраним редкие и выбивающиеся значения**

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    23699.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.724358
# std        5.682529  1.088701e+07     35.654083      1.078405        0.988298
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.700000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  23699.000000
# mean      10.673824     34.457852      5.892358     10.569807      0.591080
# ...

# %% [markdown]
# **Столбец 'total_images'**
#
# Есть объявления без фотографий, посчитаем их кол-во:

# %%
sum(data['total_images'] == 0)
# Out:
# 1059

# %% [markdown]
# Замечаний нет, некоторые объявления действительно могут быть без фотографий, оставим ебез изменений.

# %% [markdown]
# **Столбец 'last_price'**

# %% [markdown]
# Средняя цена около 6,5 миллионов руб, максимальная - 763 миллиона, минимальная - 12 тыс.
#
# Посмотрим на крайние значения поближе.

# %%
data[data['last_price'] < 450000]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 8793              7     12190.0       109.0           2019-03-20      2
# 14911             5    430000.0        54.0           2018-06-26      2
# 16274            18    440000.0        40.0           2018-07-10      1
# 17456             7    430000.0        30.4           2019-04-22      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  \
# 8793             2.75          25.0         32.0     25        False
# 14911            2.65           3.0          NaN      3        False
# 16274            2.65           5.0          NaN      1        False
# 17456            2.65           2.0         16.0      1        False
#
#        is_studio  is_open_plan  kitchen_area  balcony          locality_name  \
# 8793       False         False          40.5        0        санкт-петербург
# 14911      False         False           NaN        0  поселок станции свирь
# ...

# %%
data[data['last_price'] > 300000000]
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 1436             19  330000000.0       190.0           2018-04-04      3
# 12971            19  763000000.0       400.0           2017-09-30      7
# 14706            15  401300000.0       401.0           2016-02-20      5
# 19540             8  420000000.0       900.0           2017-12-06     12
#
#        ceiling_height  floors_total  living_area  floor is_apartment  \
# 1436             3.50           7.0         95.0      5        False
# 12971            2.65          10.0        250.0     10        False
# 14706            2.65           9.0        204.0      9          NaN
# 19540            2.80          25.0        409.7     25        False
#
#        is_studio  is_open_plan  kitchen_area  balcony    locality_name  \
# 1436       False         False          40.0        0  санкт-петербург
# 12971      False         False           NaN        2  санкт-петербург
# ...

# %% [markdown]
# Как видим крайние значения сильно выбиваются на фоне общих и кажутся неадекватными, поэтому удаляем их.

# %%
data = data.loc[data['last_price'] > 430000] 
data = data.loc[data['last_price'] < 400000000]

# %% [markdown]
# **Столбец 'total_area'**

# %%
data.hist('total_area', bins=50, range=(0,900));
data.hist('total_area', bins=50, range=(0,300));
data.hist('total_area', bins=50, range=(0,40));

# %%
data[data['total_area'] < 20]['total_area'].count()
# Out:
# 27

# %%
data[data['total_area'] > 300]['total_area'].count()
# Out:
# 58

# %% [markdown]
# Квартир менее 20 кв.м. и более 300 кв.м. - немного и их лучше удалить.

# %%
data = data[(data['total_area'] >= 20) & (data['total_area'] <= 300)]

# %% [markdown]
# **Столбец 'rooms'**

# %%
data.hist('rooms', bins=50, range=(0,20));

# %%
data.hist('rooms', bins=50, range=(6,20));

# %%
data[data['rooms'] > 7]['rooms'].count()
# Out:
# 19

# %%
data.query('rooms == 0')['rooms'].count()
# Out:
# 188

# %%
data.query('rooms == 0').head(10)
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 144              1   2450000.0       27.00           2017-03-30      0
# 349              4   2320000.0       25.00           2017-09-27      0
# 440              8   2480000.0       27.11           2018-03-12      0
# 508              0   3375000.0       34.40           2017-03-28      0
# 608              2   1850000.0       25.00           2019-02-20      0
# 697             12   2500000.0       24.10           2017-12-01      0
# 780              9   2600000.0       26.10           2018-02-20      0
# 839             14   1900000.0       35.00           2017-04-14      0
# 946              5   2200000.0       23.00           2016-09-27      0
# 1173            12   3240000.0       29.00           2018-10-30      0
#
#       ceiling_height  floors_total  living_area  floor is_apartment  \
# 144             2.65          24.0        15.50      2        False
# ...

# %% [markdown]
# Можно предположить, что с такой площадью и отсутствием площади кухни, 0 комнат означает, что это квартиры-студии. Оставим всё как есть.
# Имеем всего 19 квартир, имеющих больше 7 комнат - их не так много, считаю, что можно их убрать из общей массы

# %%
data = data[data['rooms'] < 8]

# %% [markdown]
# **Столбец 'ceiling_height'**

# %%
data.hist('ceiling_height', bins=50, range=(0,50));

# %%
data.hist('ceiling_height', bins=50, range=(0,10));

# %%
data.hist('ceiling_height', bins=50, range=(40,101));

# %%
data[data['ceiling_height'] > 4]['ceiling_height'].count()
# Out:
# 70

# %%
data[data['ceiling_height'] < 2.5]['ceiling_height'].count()
# Out:
# 73

# %% [markdown]
# Удаляем квартиры с высотой потолков до 2,5 и от 4 метров, но для квартир с высотой потолков до 25 до 40 метров предполагаем, что это опечатка и делим на 10.

# %%
data.update(data[(data['ceiling_height'] >= 25) & (data['ceiling_height'] <= 40)]['ceiling_height']/10)

# %%
data.drop(index=data.query('ceiling_height > 4 and ceiling_height < 2.5').index,inplace=True)
data.drop(index=data.query('ceiling_height > 4').index,inplace=True)
data.query('ceiling_height > 4')['ceiling_height'].count()
# Out:
# 0

# %%
data.hist('ceiling_height', bins=5, range=(5,100));

# %% [markdown]
# Все аномальные значения высот потолков были успешно удалены

# %% [markdown]
# **Столбец 'floors_total'**

# %%
data.hist('floors_total', bins=50, range=(0,60));

# %%
data.hist('floors_total', bins=20, range=(25,60));

# %% [markdown]
# Есть одноэтажные квартиры,но это не похоже на выброс. Так же есть небольшое количество квартир в 30 и более этажных домах, их немного - уберем их.

# %%
data.drop(index=data.query('floors_total > 30').index,inplace=True)

# %% [markdown]
# **Столбец 'living_area'**

# %%
data.hist('living_area', bins=60, range=(0,409));

# %%
data.hist('living_area', bins=60, range=(150,409));

# %%
data.hist('living_area', bins=60, range=(0,50));

# %%
data[data['living_area'] < 10]['ceiling_height'].count()
# Out:
# 24

# %%
data[data['living_area'] > 200]['ceiling_height'].count()
# Out:
# 2

# %% [markdown]
# Отбросим значения с жилой площадью меньше 10кв.м. и более 200 кв.м.

# %%
data.drop(index=data.query('living_area < 10 and living_area > 200').index,inplace=True)

# %% [markdown]
# **Столбец 'floor'**

# %% [markdown]
# Здесь нет нулевых значений или выбивающихся больших значений, но проверим есть ли значения этажа больше, чем этажность строения.

# %%
print(data.query('floor > floors_total')['floor'].count())
# Out:
# 0

# %% [markdown]
# Все в порядке!

# %% [markdown]
# **Столбец 'kitchen_area'**

# %%
data.hist('kitchen_area', bins=50);
data.hist('kitchen_area', bins=30, range=(0,20));
data.hist('kitchen_area', bins=30, range=(20,100));

# %%
data.query('kitchen_area > 60')['kitchen_area'].count()
# Out:
# 18

# %%
data.query('kitchen_area < 2')['kitchen_area'].count()
# Out:
# 1

# %% [markdown]
# Здесь есть одна квартира с площадью кухни меньше 1 кв. м. и 18 кухонь более 60 кв.м.
# Удалим эти строки.

# %%
data.drop(index=data.query('kitchen_area < 2').index,inplace=True)
data.drop(index=data.query('kitchen_area > 60').index,inplace=True)

# %% [markdown]
# **Столбец 'balcony'**

# %%
data.hist('balcony', bins=5);

# %% [markdown]
# Все отлично, оставляем как есть.

# %% [markdown]
# **Столбец 'days_exposition'**

# %%
data.hist('days_exposition', bins=50);
data.hist('days_exposition', bins=50, range=(800,1400));

# %%
data.query('days_exposition == 0')['days_exposition'].count()
# Out:
# 0

# %%
data.query('days_exposition > 1200')['days_exposition'].count()
# Out:
# 90

# %% [markdown]
# В целом все неплохо. Нулевых значений нет. Объявления, которым больше 1200 дней немного - удалим их

# %%
data.drop(index=data.query('days_exposition > 1200').index,inplace=True)

# %% [markdown]
# **Столбцы 'airports_nearest' и 'city_centers_nearest'**

# %%
data.hist('airports_nearest', bins=100);
data.hist('city_centers_nearest', bins=100);

# %%
data.query('airports_nearest == 0')['airports_nearest'].count()
# Out:
# 1

# %%
data.query('city_centers_nearest == 0')['city_centers_nearest'].count()
# Out:
# 0

# %%
data.drop(index=data.query('airports_nearest < 5000').index,inplace=True)

# %% [markdown]
# **Столбцы 'parks_around_3000', 'parks_nearest', 'ponds_around_3000', 'ponds_nearest'**

# %%
data.hist('parks_around_3000', bins=10);
data.hist('parks_nearest', bins=10);
data.hist('ponds_around_3000', bins=10);
data.hist('ponds_nearest', bins=10);

# %%
data.query('parks_nearest >3000 and parks_around_3000 != 0')['parks_around_3000'].count()
# Out:
# 0

# %%
data.query('ponds_nearest > 3000 and ponds_around_3000 != 0')['ponds_around_3000'].count()
# Out:
# 0

# %% [markdown]
# Cбросим индексацию после удаления строк.

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23396 entries, 0 to 23395
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23396 non-null  int64
#  1   last_price            23396 non-null  float64
#  2   total_area            23396 non-null  float64
#  3   first_day_exposition  23396 non-null  datetime64[ns]
#  4   rooms                 23396 non-null  int64
#  5   ceiling_height        23396 non-null  float64
#  6   floors_total          23311 non-null  float64
#  7   living_area           21530 non-null  float64
#  8   floor                 23396 non-null  int64
#  9   is_apartment          20664 non-null  object
#  10  is_studio             23396 non-null  bool
#  11  is_open_plan          23396 non-null  bool
#  12  kitchen_area          21174 non-null  float64
#  13  balcony               23396 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Остались потолки по 100 метров
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Исправил.
# <br>Действительно, был один выброс - квартира с высотой потолка аж в 100 м
# <br>Сейчас столбец подчищен, выбросов нет)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавляем в таблицу новые столбцы:
# - 'price_per_square_meter' - цена одного квадратного метра;
# - 'dayofweek' - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - 'month' - месяц публикации объявления;
# - 'year' - год публикации объявления;
# - 'floor_category' - тип этажа квартиры (значения — «первый», «последний», «другой»);
# - 'city_centers_nearest_km' - расстояние до центра города в километрах (переведите из м в км и округлите до целых значений).

# %% [markdown]
# Цена одного квадратного метра:

# %%
data['price_per_square_meter'] = data['last_price']/data['total_area']
data['price_per_square_meter'] = data['price_per_square_meter'].astype('int')

# %% [markdown]
# День публикации объявления (0 - понедельник, 1 - вторник и т.д.):

# %%
data['dayofweek'] = data['first_day_exposition'].dt.dayofweek

# %% [markdown]
# Месяц и год публикации объявления:

# %%
data['month'] = data['first_day_exposition'].dt.month
data['year'] = data['first_day_exposition'].dt.year

# %% [markdown]
# Тип этажа квартиры (значения — «первый», «последний», «другой»):

# %%
data['floor_category'] = data.apply(
    lambda x: 1 if (x.floor == 1) 
    else (2 if (x.floor == x.floors_total)
    else 3), axis=1
)

last_floor = data.query('floors_total/floor == 1')
data['floor_category'] = data['floor']
data.loc[data['floor_category'] == 1, 'floor_category'] = 'Первый'
data.loc[data['floor_category'] == data['floors_total'], 'floor_category'] = 'Последний'
data.loc[(data['floor_category'] != 'Первый') & (data['floor_category']!='Последний'), 'floor_category'] = 'Другой'

# %%
data['floor_category'].value_counts()
# Out:
# Другой       17254
# Последний     3262
# Первый        2880
# Name: floor_category, dtype: int64

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Должно быть только 3 категории этажей, а у тебя 2. Сделай следующий образом. Если этаж равен 1, то "первый", если floors_total равно этажу, то "последний". В остальных случаях "другой"
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Спасибо за замечание! Пропустил моментик...
# <br>Исправил, сейчас выводится без ошибок.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# Расстояние до центра города в километрах:

# %%
data['city_centers_nearest_km'] = round(data['city_centers_nearest'] / 1000)
data['city_centers_nearest_km'] = data['city_centers_nearest_km'].astype('Int32')

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# Изучим общие параметры объектов:

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23396.000000  2.339600e+04  23396.000000  23396.000000    23396.000000
# mean       9.861130  6.209619e+06     59.071131      2.050650        2.691046
# std        5.676225  7.388043e+06     29.576505      1.018424        0.201723
# min        0.000000  4.400000e+05     20.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.600000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.700000e+06     69.000000      3.000000        2.700000
# max       50.000000  3.300000e+08    300.000000      7.000000        4.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23311.000000  21530.000000  23396.000000  21174.000000  23396.000000
# mean      10.674446     33.800642      5.890109     10.419517      0.592195
# ...

# %%
data.hist('total_area', bins=100);
plt.xlabel('м²')
plt.ylabel('Кол-во квартир')
plt.title('Общая площадь')

data.hist('living_area', bins=100);
plt.xlabel('м²')
plt.ylabel('Кол-во квартир')
plt.title('Жилая площадь')

data.hist('living_area', bins=50, range=(0,50));
plt.xlabel('м²')
plt.ylabel('Кол-во квартир')
plt.title('Жилая площадь')

data.hist('kitchen_area', bins=100);
plt.xlabel('м²')
plt.ylabel('Кол-во квартир')
plt.title('Площадь кухни')

data.hist('kitchen_area', bins=20, range=(0,20));
plt.xlabel('м²')
plt.ylabel('Кол-во квартир')
plt.title('Площадь кухни')

data.hist('last_price', bins=100, range=(0,2e+07));
plt.xlabel('Млн. ₽')
plt.ylabel('Кол-во квартир')
plt.title('Цена объекта')

data.hist('rooms', bins=data['rooms'].max());
plt.xlabel('Кол-во комнат')
plt.ylabel('Кол-во квартир')
plt.title('Количество комнат')

data.hist('ceiling_height', bins=30, range=(2,4));
plt.xlabel('м')
plt.ylabel('Кол-во квартир')
plt.title('Высота потолков')

data.hist('floor', bins=data['floor'].max());
plt.xlabel('Этаж')
plt.ylabel('Кол-во квартир')
plt.title('Этаж квартиры')

data.groupby(by='floor_category')['floor_category'].count().plot(kind='bar');
plt.xlabel('Тип этажа')
plt.ylabel('Кол-во квартир')
plt.title('Тип этажа квартиры')

data.hist('floors_total', bins=30);
plt.xlabel('Кол-во этажей')
plt.ylabel('Кол-во квартир')
plt.title('Общее кол-во этажей в доме')

data.hist('city_centers_nearest', bins=100);
plt.xlabel('м')
plt.ylabel('Кол-во квартир')
plt.title('Расстояние до центра города')

data.hist('airports_nearest', bins=100);
plt.xlabel('м')
plt.ylabel('Кол-во квартир')
plt.title('Расстояние до ближайшего аэропорта')

data.hist('parks_nearest', bins=100);
plt.xlabel('м');
plt.ylabel('Кол-во квартир')
plt.title('Расстояние до ближайшего парка')

data.hist('parks_nearest', bins=100, range=(1, 3000));
plt.xlabel('м');
plt.ylabel('Кол-во квартир')
plt.title('Расстояние до ближайшего парка')

data.hist('dayofweek', bins=7);
plt.xlabel('День недели')
plt.ylabel('Кол-во объявлений')
plt.title('День публикации объявления')

data.hist('month', bins=12);
plt.xlabel('Месяц')
plt.ylabel('Кол-во объявлений')
plt.title('Месяц публикации объявления')

plt.show()

# %% [markdown]
# Построили гистограммы для столбцов:
#
# - **общая площадь**;
# По графику видим, что достаточно мало квартир с общей площадью более 100 кв.м., намного меньше квартир с площадью более 150 кв.м. - но это, скорее-всего, просто элитная недвижимость
# - **жилая площадь**;
# На графике видно два пика - 18 кв.м. и 30 кв.м. Стоить проверить, почему имеют место эти пики, а так же разобраться в причине провала в районе 24 кв.м.
# - **площадь кухни**;
# К данному стобцу вопросов нет, все выглядит неплохо.
# - **цена объекта**;
# Все нормально, график выглядит неплохо.
# - **количество комнат**;
# Больше всего двух- и трёх-комнатных квартир, но встречаются и редкие исключения.
# - **высота потолков**;
# Два пика - 2.5м и 3м, но это логично.
# - **этаж квартиры**;
# По графику видно, что больше всего квартир с 1 по 5 этаж.
# - **тип этажа квартиры («первый», «последний», «другой»)**;
# Больше всего квартир на "другом" этаже, это нормально.
# - **общее количество этажей в доме**;
# На графике явные пики: 5-этажная застройка, 9-этажная застройка и небольшие пики более высоких новостроек.
# - **расстояние до центра города в метрах**;
# Здесь наблюдаем два пика, один маленький, 5км и другой побльшой от 10 км. до 15 км. Так же есть совсем небольшие всплески на 30 км. и 50 км.
# - **расстояние до ближайшего аэропорта**;
# Все нормально.
# - **расстояние до ближайшего парка**;
# Судя по графику больше всего квартир с парками на расстоянии до 750м, но так же очень много квартир, рядом с которыми парков нет.
# - **день и месяц публикации объявления**;
# По графику видно, что объявления в субботу и воскресенье публикуются меньше, что объянимо. По графику месяцев же видим что с февраля по апрель наблюдалосась повышенная активность. Так же был плавный рост активности с июля по ноябрь. Есть небольшие провалы в декабре, январе и мае.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Ты корректно подбираешь основные диапазоны, а также верно читаешь графики!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Для того чтобы подписать график мы можем использовать метод plt.title() и в конце кода применить plt.show(). По ссылкам ниже можно почитать подробнее как добавить название для графика или подписать его оси
#
#     https://pyprog.pro/mpl/mpl_title.html
#     https://pyprog.pro/mpl/mpl_axis_signatures.html
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Спасибо! Оформил графики покрасивее и немного дополнил)
# <br>Единственное, что не могу понять - почему у меня график 'тип этажа квартиры' немного слетел?
# <br>Все ломаю голову, а понять так никак и не могу
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v2:</b>
# <br>Если его вывести отдельно, то он отображется корректно)
# </div>

# %%
data.groupby(by='floor_category')['floor_category'].count().plot(kind='bar');
plt.xlabel('Тип этажа')
plt.ylabel('Кол-во квартир')
plt.title('Тип этажа квартиры')
# Out:
# Text(0.5, 1.0, 'Тип этажа квартиры')

# %% [markdown]
# **Изученим, как быстро продавались квартиры**

# %% [markdown]
# Построим график значений для столбца с высотой потолков

# %%
data.hist('days_exposition', bins=100);
data.hist('days_exposition', bins=100, range = (0,200));
data.hist('days_exposition', bins=100, range = (200, 600));

print('Среднее:',int(data['days_exposition'].mean()))
print('Медиана:',int(data['days_exposition'].median()))
# Out:
# Среднее: 175
# Медиана: 94

# %% [markdown]
# Среднее время продажи квартиры составляет 175 день - это примерно полгода. Но медиана равна 95 дням, т.е. почти в два раза меньше. Так получилось, потому что есть длинный хвост квартир, которые продавались по несколько лет.
# Быстрыми будем считать продажи до медианы, т.е. до 95 дней, а необычно долгими - свыше одного года.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>А как бы ты объяснил эти пики в районе 45 и 60 дней?
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Скорее-всего связано с правилами размещения объявлений Яндекс.Недвижимости.
# <br>В правилах написано, что для квартир стоимостью до 4.5млн рублей - 45 дней, а для квартир стоимостью от 4.5млн до 10млн - 60 дней
# <br>Думаю, что данные пики можно не считать за аномальные значения.
# <br>Ниже извлек несколько строк для 45 и 60 дней, посмотрев на них думаю, что все-таки дело в правилах Яндекс.Недвижимости.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Верно!
# </div>

# %%
data['days_exposition'].value_counts().head(5)
# Out:
# 45.0    876
# 60.0    536
# 7.0     228
# 30.0    207
# 90.0    201
# Name: days_exposition, dtype: int64

# %%
data.query('days_exposition > 44 & days_exposition < 46')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 54                6   3320000.0        36.5           2017-04-14      1
# 78                9   4350000.0        37.0           2018-02-22      1
# 89                9   2500000.0        63.0           2018-10-25      3
# 110               6   3850000.0        72.3           2017-09-29      2
# 153              12   4350000.0        55.0           2017-05-21      2
# ...             ...         ...         ...                  ...    ...
# 23310             4   3950000.0        52.0           2018-03-04      3
# 23316             6   3000000.0        31.8           2018-10-17      1
# 23367             9   2450000.0        45.6           2018-02-08      1
# 23376             0   2500000.0        35.0           2017-12-08      1
# 23392            14   3100000.0        59.0           2018-01-15      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  \
# ...

# %%
data.query('days_exposition > 59 & days_exposition < 61')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22               20   5000000.0        58.0           2017-04-24      2
# 82                3   4500000.0        80.5           2018-01-15      3
# 105              12   4900000.0        32.0           2018-01-07      1
# 118               8   4500000.0        31.0           2019-02-24      1
# 143               9   2990000.0        30.0           2016-06-08      1
# ...             ...         ...         ...                  ...    ...
# 23274            10   3750000.0        45.0           2016-06-14      2
# 23297             8   8700000.0       132.0           2018-11-13      3
# 23318            11   5000000.0        37.9           2017-08-31      1
# 23332             9   5100000.0        36.0           2018-10-26      1
# 23339            14   5950000.0        80.3           2018-07-03      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  \
# ...

# %% [markdown]
# **Факторы оторые больше всего влияют на общую (полную) стоимость объекта**

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Рассчитывать корреляцию Пирсона для дня недели, месяца и года продажи не эффективно, так как цена в данном случае зависит от них не линейно. Чтобы изучить зависимость для этих параметров лучше построить bar plot или гистограмму рассчитав среднее значение или медиану. Графики у тебя уже есть, поэтому остаётся только удалить расчет корреляции)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Спасибо за замечание.
# <br>Действительно, это так. Рассчет корреляции, который был выше - удалил)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# Построим графики, которые покажут зависимость цены от указанных выше параметров

# %%
data.plot(x='last_price', y='total_area', kind='scatter', alpha=0.2)
data.plot(x='last_price', y='living_area', kind='scatter', alpha=0.2)
data.plot(x='last_price', y='kitchen_area', kind='scatter', alpha=0.2)
# Out:
# <AxesSubplot:xlabel='last_price', ylabel='kitchen_area'>

# %%
data.pivot_table(index='rooms',values='last_price').plot(y='last_price', kind='bar');

# %%
data.pivot_table(index='floor_category',values='last_price').plot(y='last_price', kind='barh');

data.plot(x='last_price', y='floor_category', kind='scatter', alpha=0.2)
# Out:
# <AxesSubplot:xlabel='last_price', ylabel='floor_category'>

# %%
data.pivot_table(index='dayofweek',values='last_price',aggfunc='mean').plot(y='last_price', kind='line', title='mean');
data.pivot_table(index='dayofweek',values='last_price',aggfunc='median').plot(y='last_price', kind='line', title='median');

data.pivot_table(index='month',values='last_price',aggfunc='mean').plot(y='last_price', kind='line', title='mean');
data.pivot_table(index='month',values='last_price',aggfunc='median').plot(y='last_price', kind='line', title='median');

data.pivot_table(index='year',values='last_price',aggfunc='mean').plot(y='last_price', kind='line', title='mean');
data.pivot_table(index='year',values='last_price',aggfunc='median').plot(y='last_price', kind='line', title='median');

# %% [markdown]
# Исходя из данных графиков, можем сказать, что цена зависит от общей площади, жилой площади, площади кухни и количества комнат.
# И практически не зависит от этажа, на котором расположена квартира и даты размещения объявления о продаже.
# Больше всего на общую (полную) стоимость объекта влияют общая и жилая площади, менее всего - площадь кухни и кол-во комнат.

# %% [markdown]
# **Cчитаем среднюю цену одного квадратного метра в 10 населенных пунктах с наибольшим числом объявлений**

# %%
top_10 = data.pivot_table(index='locality_name', values=['last_price','total_area'] ,aggfunc=['sum','count'])
top_10.columns=['last_price_sum','total_area_sum','last_price_count','total_area_count']
top_10.pop('total_area_count')
top_10.sort_values(by=['last_price_count'],ascending=False, inplace=True)
top_10 = top_10.iloc[:10]
top_10['price_per_sq_m'] = top_10['last_price_sum']/top_10['total_area_sum']
top_10.sort_values(by=['price_per_sq_m'],ascending=True, inplace=True)
top_10['price_per_sq_m'].plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='locality_name'>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👏🏻👏🏻👏🏻 Отличная визуализация!
# </div>

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00           2019-03-07      3
# 1             7   3350000.0       40.40           2018-12-04      1
# 2            10   5196000.0       56.00           2015-08-20      2
# 3             0  64900000.0      159.00           2015-07-24      3
# 4             2  10000000.0      100.00           2018-06-19      2
# 5            10   2890000.0       30.40           2018-09-10      1
# 6             6   3700000.0       37.30           2017-11-02      1
# 7             5   7915000.0       71.60           2019-04-18      2
# 8            20   2900000.0       33.16           2018-05-23      1
# 9            18   5400000.0       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  is_studio  \
# 0            2.70          16.0        51.00      8        False      False
# ...

# %%
data['rooms'].value_counts()
# Out:
# 1    7989
# 2    7878
# 3    5752
# 4    1160
# 5     298
# 0     185
# 6      92
# 7      42
# Name: rooms, dtype: int64

# %%
data.groupby(by='rooms')['rooms'].count().sort_values(ascending=False)
# Out:
# rooms
# 1    7989
# 2    7878
# 3    5752
# 4    1160
# 5     298
# 0     185
# 6      92
# 7      42
# Name: rooms, dtype: int64

# %%
display(top_10)
# Out:
#                    last_price_sum  total_area_sum  last_price_count  \
# locality_name
# выборг               7.638830e+08        13212.56               236
# всеволожск           1.501549e+09        22207.03               396
# гатчина              1.070919e+09        15639.48               307
# колпино              1.302939e+09        17644.74               337
# поселок шушары       1.806056e+09        23664.36               439
# поселок мурино       2.030713e+09        24442.54               556
# поселок парголово    1.463200e+09        16808.87               326
# деревня кудрово      1.266013e+09        13924.95               299
# пушкин               2.213868e+09        21146.30               359
# санкт-петербург      1.173307e+11       973672.75             15464
#
#                    price_per_sq_m
# locality_name
# выборг               57814.912477
# всеволожск           67615.929055
# гатчина              68475.381534
# колпино              73842.926901
# ...

# %% [markdown]
# В итоге получили, что самая большая цена на кв.м в Санкт-Петербурге. а самая низкая - в Выборге

# %% [markdown]
# **Как стоимость объектов зависит от расстояния до центра города**

# %%
(
    data[data['locality_name']=='санкт-петербург']
    .pivot_table(
        index='city_centers_nearest_km',
        values='last_price',
        aggfunc='mean')
    .plot(kind='bar', grid=True, title='Зависимость цены 1 кв.м. от удаленности от центра')    
).set(xlabel='км');

# %% [markdown]
# Дороже всего недвижимость в радиусе до 1км.
# Далее идет условно 'средняя' ценовая зона от 1 км до 7 км от центра Санкт-Петербурга, ее можно назвать Центральной.
# На расстоянии от 8 км цены начинают заметно падать.
# Также на диаграмме виден выброс средней цены в районе 27 км, связанный с тем, что в этой позиции находится единственный и дорогой объект недвижимости

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Верно 👍
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В процессе предварительной обработки данных были выявлены явные и неявные пропуски, а так же значения, не соответствующие действительности. Скорее всего, данные взяты из разных источников, т.к. были пропуски значений во многих столбцах, а также предположительные технические ошибки при выгрузке и из-за некорректного заполнения первоисточников клиентом. Все указанные проблемы были устранены.
#
# Так же данные были очищены от явных "выбросов" - это дорогие квартиры, которые портили корреляции и графики зависимости полной стоимости от разных параметров. Так же были выбросы и странные значения высот потолков.
#
# Для дальнейшего анализа рассчитаны и добавлены отдельными столбцами значения цены 1 кв.м., дня недели, месяца и года объявления, тип этажа квартиры и расстояние до центра города в километрах.
#
# Можем сказать, что цена зависит от общей площади, жилой площади, площади кухни и количества комнат, причем больше всего на общую (полную) стоимость объекта влияют общая и жилая площади.
# Так же присутствует зависимость цены от удаленности от центра, на примере Санкт-Петербурга мы выяснили, что самая большая цена на недвижимость находится в радиусе до 8 км от центра.
#
# Мы выяснили, что среднее время продажи квартиры составляет 175 день (примерно полгода). Много быстрых продаж - до 95 дней, но есть и необычно долгие - свыше одного года. Есть выбросы в районе 45 и 60 дней, но это с большей вероятностью связано с правилами размещения объявлений Яндекс.Недвижимости.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>После всех внесённых правок, обязательно перепроверь общий вывод и промежуточные выводы и поправь их по необходимости
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v1:</b>
# <br>Ты хорошо потрудился, большая часть работы сделана, но остаётся внести следующие правки:
# <br>- написать короткий вывод после первичного просмотра данных
# <br>- заполнить пропуски в столбце ceiling_height
# <br>- отбросить аномальные значения
# <br>- поправить категоризацию этажей
# <br>- удалить расчет корреляции для времени продажи
# <br>- поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Спасибо за замечания, Илья)
# <br>Указанные тобой правки внесены. Общий вывод немного дополнил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Итоговый комментарий ревьюера v2:</b>
# <br>Все правки выполнены. Молодец!
# <br>Проделана огромная работа! У тебя подробные, понятные и логичные выводы, которые ты подкрепляешь фактами. Были использованы разные графики и способы, чтобы как можно более тщательно изучить данные и у тебя это получилось!
# <br>Я рад был поработать над проверкой твоей работы) В качестве дополнительного материала для изучения могу порекомендовать следующий ресурс:
#
# 	https://www.python-graph-gallery.com/
# <br>В нем содержится большая библиотека графиков с готовым кодом, который можно использовать при работе.
# <br>Поздравляю со сдачей проекта и желаю удачи в дальнейшем обучении! 😉
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
